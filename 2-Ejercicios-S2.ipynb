# %% [markdown]
# <img src="images/skillnest_logo.svg" width="260px" align="left"/>
# <div align="center" style="padding-top:20px">
# <h2>Bootcamp Data Science — Módulo 1</h2>
# <h1>Ejercicios Semana 2 — Pandas</h1>
# <br/>
# <b>Nombre:</b> ________________________________&nbsp;&nbsp;&nbsp;
# <b>Fecha:</b> ________________________________
# </div>

# %% [markdown]
# > Usa los datasets `data/pokemon.csv` y `data/titanic.csv` para resolver los ejercicios.
# > Importa pandas **una sola vez** al inicio de cada ejercicio con `import pandas as pd`.

# %% [markdown]
# ---
# ## Clase 1 — Introducción a Pandas

# %% [markdown]
# ### Ejercicio 1.1 — Tu primer DataFrame
#
# Crea **desde cero** (sin leer ningún archivo) un DataFrame con la información de 5 de tus compañeros de clase (puedes inventarlos):
# - `nombre` (str)
# - `edad` (int)
# - `ciudad` (str)
# - `tiene_computador` (bool)
#
# Luego:
# 1. Imprime el shape
# 2. Muestra solo los mayores de 22 años
# 3. Muestra la columna `nombre` como Serie

# %%
# Ejercicio 1.1
import pandas as pd

# Tu código aquí:
info = pd.DataFrame({
    'Nombre': ['Alice', 'Bob', 'Charlie', 'Daniel', 'Emilia'],
    'Edad': [25, 30, 28, 21, 20],
    'Ciudad': ['Santiago', 'Valparaiso', 'Santiago', 'Concepcion', 'Valdivia'],
    'tiene_computadora': [True, False, True, False, True]
})

# %%
info.shape
# Out:
# (5, 4)

# %%
print(info[info['Edad'] > 22])
# Out:
#     Nombre  Edad      Ciudad  tiene_computadora
# 0    Alice    25    Santiago               True
# 1      Bob    30  Valparaiso              False
# 2  Charlie    28    Santiago               True

# %%
nombre = info['Nombre']
print(nombre)
print(type(nombre))
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3     Daniel
# 4     Emilia
# Name: Nombre, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Ejercicio 1.2 — Explorando Pokémon
#
# Carga `data/pokemon.csv` y responde **sin mirar la respuesta**, solo usando código:
#
# 1. ¿Cuántas filas y columnas tiene el dataset?
# 2. ¿Cuáles son los nombres de todas las columnas?
# 3. ¿Cuántos valores nulos hay en total en todo el dataset?
# 4. ¿Cuál es el HP promedio de todos los pokémon?
# 5. ¿Cuántas generaciones distintas hay?
#
# Imprime cada respuesta con un texto descriptivo.

# %%
# Ejercicio 1.2
import pandas as pd
df = pd.read_csv("data/pokemon.csv")

# Tu código aquí:
df.shape
# Out:
# (800, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.isna().sum().sum()
# Out:
# np.int64(386)

# %%
print(df['HP'].mean())
# Out:
# 69.25875

# %%
print(df['Generation'].unique())
# Out:
# [1 2 3 4 5 6]

# %%
print(df['Generation'].value_counts())
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# ### Ejercicio 1.3 — Selección de datos
#
# Con el dataset Pokémon:
# 1. Muestra las columnas `Name`, `Type 1`, `HP`, `Attack`, `Defense` de los primeros 15 pokémon
# 2. Usa `loc` para seleccionar las filas 10 a 20 y las columnas `Name` y `Total`
# 3. Usa `iloc` para seleccionar las últimas 5 filas y las últimas 3 columnas
# 4. ¿Cuál es el nombre del pokémon en la posición 99 (índice 99)?

# %%
# Ejercicio 1.3
import pandas as pd
df = pd.read_csv("data/pokemon.csv")

# %%
df[['Name', 'Type 1', 'HP', 'Attack', 'Defense']].head(15)
# Out:
#                          Name Type 1  HP  Attack  Defense
# 0                   Bulbasaur  Grass  45      49       49
# 1                     Ivysaur  Grass  60      62       63
# 2                    Venusaur  Grass  80      82       83
# 3       VenusaurMega Venusaur  Grass  80     100      123
# 4                  Charmander   Fire  39      52       43
# 5                  Charmeleon   Fire  58      64       58
# 6                   Charizard   Fire  78      84       78
# 7   CharizardMega Charizard X   Fire  78     130      111
# 8   CharizardMega Charizard Y   Fire  78     104       78
# 9                    Squirtle  Water  44      48       65
# 10                  Wartortle  Water  59      63       80
# 11                  Blastoise  Water  79      83      100
# 12    BlastoiseMega Blastoise  Water  79     103      120
# 13                   Caterpie    Bug  45      30       35
# 14                    Metapod    Bug  50      20       55

# %%
df.loc[10:20, ['Name', 'Total']]
# Out:
#                        Name  Total
# 10                Wartortle    405
# 11                Blastoise    530
# 12  BlastoiseMega Blastoise    630
# 13                 Caterpie    195
# 14                  Metapod    205
# 15               Butterfree    395
# 16                   Weedle    195
# 17                   Kakuna    205
# 18                 Beedrill    395
# 19    BeedrillMega Beedrill    495
# 20                   Pidgey    251

# %%
df.iloc[-5:, -3:]
# Out:
#      Speed  Generation  Legendary
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True

# %%
df.loc[99, 'Name']
# Out:
# 'Gastly'

# %% [markdown]
# ---
# ## Clase 2 — Filtrado

# %% [markdown]
# ### Ejercicio 2.1 — Filtros simples
#
# Con el dataset Pokémon, crea **una variable de filtro** para cada caso y aplícalo:
#
# 1. Pokémon de tipo Agua (`Type 1 == 'Water'`)
# 2. Pokémon con `Defense` mayor a 100
# 3. Pokémon de la Generación 3
# 4. Pokémon que NO son legendarios
#
# Para cada caso imprime cuántos pokémon cumplen la condición.

# %%
# Ejercicio 2.1
import pandas as pd
df = pd.read_csv("data/pokemon.csv")

# %%
df[df['Type 1'] == 'Water']
print(f'Existen {len(df[df["Type 1"] == "Water"])} pokemones de tipo agua.')
# Out:
# Existen 112 pokemones de tipo agua.

# %%
df[df['Defense'] > 100]
print(f'Existen {len(df[df["Defense"] > 100])} pokemones con defensa mayor a 100.')
# Out:
# Existen 123 pokemones con defensa mayor a 100.

# %%
df.value_counts('Generation')
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
df[df['Generation']== 3]
print(f'Existen {len(df[df["Generation"] == 3])} pokemones de la generación 3.')
# Out:
# Existen 160 pokemones de la generación 3.

# %%
df[df['Legendary'] == False]
print(f'Existen {len(df[df["Legendary"] == False])} pokemones que no son legendarios, de un total de {len(df)} pokemones.')
# Out:
# Existen 735 pokemones que no son legendarios, de un total de 800 pokemones.

# %% [markdown]
# ### Ejercicio 2.2 — Filtros combinados
#
# 1. Pokémon de tipo Psíquico (`Psychic`) de la **Generación 1**
# 2. Pokémon con `HP` > 80 **Y** `Speed` > 80 (¡los más equilibrados!)
# 3. Pokémon de tipo **Dragón o Fantasma** (`Dragon` o `Ghost`)
# 4. Pokémon que tienen `Speed` < 40 pero `Defense` > 120 (tanques lentos)
# 5. Pokémon cuyo nombre **no** contiene la letra `"a"` (mayúscula o minúscula)
#
# Para el punto 5 usa `.str.lower().str.contains()`

# %%
# Ejercicio 2.2
import pandas as pd
df = pd.read_csv("data/pokemon.csv")

# %% [markdown]
# ### Ejercicio 2.3 — Exploración con value_counts
#
# 1. ¿Cuál es el tipo (`Type 1`) más común?
# 2. ¿Qué porcentaje del total representa el tipo más común? Usa `normalize=True`
# 3. ¿Cuántos pokémon únicos hay por generación?
# 4. ¿Cuál es el tipo que tiene el mayor promedio de `Attack`?
#    **Pista:** `df.groupby('Type 1')['Attack'].mean().sort_values(ascending=False)`

# %%
# Ejercicio 2.3
import pandas as pd
df = pd.read_csv("data/pokemon.csv")

# Tu código aquí:

# %% [markdown]
# ---
# ## Clase 3 — Limpieza de Datos

# %% [markdown]
# ### Ejercicio 3.1 — Diagnóstico de nulos
#
# Carga `data/titanic.csv` y:
# 1. Imprime cuántos nulos hay en cada columna
# 2. Calcula el **porcentaje de nulos** por columna (solo las que tienen nulos)
# 3. ¿Qué columna tiene el mayor porcentaje de nulos? ¿Qué harías con ella?
# 4. Filtra y muestra las filas donde `Embarked` es nulo — ¿qué tienen en común?

# %%
# Ejercicio 3.1
import pandas as pd
df = pd.read_csv("data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum() #cantidad de nulos por columnas
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100 #porcentaje de nulos por columnas
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
#Filtra y muestra las filas donde `Embarked` es nulo
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ### Ejercicio 3.2 — Rellenar nulos
#
# Con el Titanic:
# 1. Rellena `Age` con la **mediana** separada por sexo (`Sex`)
#    **Pista:** `df.groupby('Sex')['Age'].transform('median')`
# 2. Rellena `Embarked` con la **moda**
# 3. Elimina la columna `Cabin` (tiene demasiados nulos)
# 4. Verifica que no queden nulos con `isnull().sum()`

# %%
# Ejercicio 3.2
import pandas as pd
df = pd.read_csv("data/titanic.csv")

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#mostrar promedio de edad separado por Sexo
df.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
#cambiar los null de 'Age' por la mediana de edad por sexo
df['Age'] = df.groupby('Sex')['Age'].transform('median')

# %% [markdown]
# ### Ejercicio 3.3 — Pipeline completo de limpieza
#
# Construye un pipeline que limpie el Titanic de principio a fin:
#
# 1. Elimina las columnas `PassengerId`, `Name`, `Ticket`, `Cabin`
# 2. Rellena `Age` con la mediana
# 3. Rellena `Embarked` con la moda
# 4. Elimina duplicados
# 5. Renombra todas las columnas al español
# 6. Convierte `Survived` a `bool`
# 7. Al final imprime:
#    - El shape del dataset limpio
#    - Los tipos de datos
#    - Que no quedan nulos (`assert df.isnull().sum().sum() == 0`)

# %%
# Ejercicio 3.3
import pandas as pd
df = pd.read_csv("data/titanic.csv")

# Tu código aquí:

# %% [markdown]
# ---
# ## 🏆 Desafío Final
#
# ### Análisis completo: ¿Quién sobrevivió al Titanic?
#
# Usando el dataset limpiado del ejercicio 3.3, responde las siguientes preguntas **con código**. Cada respuesta debe imprimirse con una oración descriptiva.
#
# 1. ¿Cuántos pasajeros sobrevivieron en total? ¿Qué porcentaje?
#
# 2. ¿La tasa de supervivencia fue diferente entre hombres y mujeres?
#    Imprime el porcentaje de sobrevivientes por sexo.
#
# 3. ¿Los pasajeros de primera clase tuvieron mayor probabilidad de sobrevivir?
#    Calcula la tasa de supervivencia por clase.
#
# 4. ¿Cuál era la edad promedio de quienes sobrevivieron vs los que no?
#
# 5. ¿Los pasajeros que viajaban solos (sin hermanos ni hijos) sobrevivieron menos?
#    Define "viajando solo" como `hermanos == 0 AND hijos == 0`.
#
# 6. **Bonus:** Crea una columna `grupo_edad` con:
#    - `"Niño"` si edad < 18
#    - `"Adulto"` si 18 ≤ edad < 60
#    - `"Adulto mayor"` si edad ≥ 60
#    ¿Qué grupo tuvo la mayor tasa de supervivencia?

# %%
# Desafío Final
import pandas as pd
df = pd.read_csv("data/titanic.csv")

# Aplica primero el pipeline de limpieza del Ejercicio 3.3
# Luego responde cada pregunta:

# %%
from IPython.core.display import HTML
HTML("""<style>
.output_png { display: table-cell; text-align: center; vertical-align: middle; }
table { border-collapse: collapse; }
</style>""")
