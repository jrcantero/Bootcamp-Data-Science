# %% [markdown]
# <img src="images/skillnest_logo.svg" width="260px" align="left"/>
# <div align="center" style="padding-top:20px">
# <h2>Bootcamp Data Science — Módulo 1</h2>
# <h1>Ejercicios Semana 1 — Python Basics</h1>
# <br/>
# <b>Nombre:</b> ________________________________&nbsp;&nbsp;&nbsp;
# <b>Fecha:</b> ________________________________
# </div>

# %% [markdown]
# > Resuelve cada ejercicio en la celda de código correspondiente.
# > Ejecuta la celda con `Shift + Enter` para verificar tu resultado.
# > No uses librerías externas — solo Python puro.

# %% [markdown]
# ---
# ## Clase 1 — Introducción & Google Colab

# %% [markdown]
# ### Ejercicio 1.1 — Tu primera presentación
#
# Imprime en pantalla:
# ```
# Hola, soy [tu nombre]
# Estoy estudiando Data Science en SKILLNEST
# Mi lenguaje favorito (o el que voy a aprender) es Python
# ```
# Usa **3 líneas de `print()`** distintas.

# %%
# Ejercicio 1.1

# %% [markdown]
# ### Ejercicio 1.2 — Operaciones básicas
#
# Calcula e imprime los resultados de:
# 1. `345 + 678`
# 2. `1000 - 437`
# 3. `25 * 4`
# 4. `17 / 3`  (división real)
# 5. `17 // 3` (división entera)
# 6. `17 % 3`  (¿qué representa este resultado?)
# 7. `2 ** 10`
#
# Cada resultado debe ir en su propia línea con un texto descriptivo.
# Ejemplo: `"345 + 678 = 1023"`

# %%
# Ejercicio 1.2

# %% [markdown]
# ---
# ## Clase 2 — Variables y Tipos de Datos

# %% [markdown]
# ### Ejercicio 2.1 — Perfil de alumno
#
# Crea las siguientes variables con **tus propios datos**:
# - `nombre` (str) — tu nombre
# - `edad` (int) — tu edad
# - `ciudad` (str) — tu ciudad
# - `altura` (float) — tu altura en metros
# - `tiene_experiencia_programacion` (bool) — ¿ya programabas antes?
#
# Luego imprime todo con f-strings en este formato:
# ```
# ===== MI PERFIL =====
# Nombre:       Ana García
# Edad:         25 años
# Ciudad:       Santiago
# Altura:       1.65 m
# Experiencia:  False
# =====================
# ```

# %%
# Ejercicio 2.1

# %% [markdown]
# ### Ejercicio 2.2 — Calculadora de descuentos
#
# Dado un precio original y un porcentaje de descuento:
# ```python
# precio_original = 89_990
# descuento_pct   = 0.30   # 30%
# ```
# Calcula e imprime:
# 1. El monto del descuento
# 2. El precio final (después del descuento)
# 3. El precio final con IVA (19%) sobre el precio descontado
#
# Usa f-strings con formato de miles (`:,.0f`)

# %%
# Ejercicio 2.2
precio_original = 89_990
descuento_pct   = 0.30

# Tu código aquí:

# %% [markdown]
# ### Ejercicio 2.3 — Conversión de tipos
#
# Tienes estos datos tal como llegarían de un CSV:
# ```python
# id_cliente     = "10482"
# saldo          = "250000.75"
# dias_atraso    = "0"
# activo         = "True"
# ```
# 1. Convierte cada variable al tipo correcto
# 2. Verifica con `type()` que la conversión fue exitosa
# 3. Calcula: ¿cuánto es el saldo con un interés del 2.5% mensual si tiene 0 días de atraso? ¿Y si tiene 30?

# %%
# Ejercicio 2.3
id_cliente  = "10482"
saldo       = "250000.75"
dias_atraso = "0"
activo      = "True"

# Tu código aquí:

# %% [markdown]
# ---
# ## Clase 3 — Estructuras de Datos y Entrada/Salida

# %% [markdown]
# ### Ejercicio 3.1 — Lista de temperaturas
#
# Tienes las temperaturas registradas durante una semana:
# ```python
# temperaturas = [18.5, 22.1, 19.8, 25.4, 17.2, 23.0, 20.6]
# dias = ["Lun", "Mar", "Mié", "Jue", "Vie", "Sáb", "Dom"]
# ```
# Sin usar `max()`, `min()` ni `sum()` — calcula **manualmente con un `for`**:
# 1. La temperatura máxima y qué día ocurrió
# 2. La temperatura mínima y qué día ocurrió
# 3. El promedio semanal
# 4. Cuántos días superaron los 20°C
# 5. Imprime un reporte con todos los resultados

# %%
# Ejercicio 3.1
temperaturas = [18.5, 22.1, 19.8, 25.4, 17.2, 23.0, 20.6]
dias         = ["Lun", "Mar", "Mié", "Jue", "Vie", "Sáb", "Dom"]

# Tu código aquí:

# %% [markdown]
# ### Ejercicio 3.2 — Diccionario de contactos
#
# Crea un diccionario `inventario` con al menos 5 productos de una tienda.
# Cada producto debe tener como llave el nombre y como valor un diccionario con:
# - `precio` (float)
# - `stock` (int)
# - `categoria` (str): "electronica", "ropa", "alimentos"
#
# Luego:
# 1. Imprime todos los productos con formato de tabla
# 2. Calcula el **valor total del inventario** (precio × stock para cada producto)
# 3. Encuentra el producto más caro y el más barato
# 4. Lista solo los productos con stock < 10

# %%
# Ejercicio 3.2
inventario = {}

# Tu código aquí:

# %% [markdown]
# ### Ejercicio 3.3 — Limpieza de texto
#
# Tienes los siguientes datos sucios (como llegarían de un formulario web):
# ```python
# datos = [
#     "  JUAN PÉREZ   ",
#     "ana.garcia@GMAIL.COM  ",
#     "  +56 9 1234 5678",
#     "  SANTIAGO, CHILE  "
# ]
# ```
# Para cada elemento:
# 1. Elimina espacios innecesarios con `.strip()`
# 2. Normaliza a minúsculas
# 3. Para el email: extrae usuario y dominio por separado
# 4. Para el teléfono: elimina espacios y el `+` inicial
# 5. Para la dirección: separa ciudad y país en variables distintas

# %%
# Ejercicio 3.3
datos = [
    "  JUAN PÉREZ   ",
    "ana.garcia@GMAIL.COM  ",
    "  +56 9 1234 5678",
    "  SANTIAGO, CHILE  "
]

# Tu código aquí:

# %% [markdown]
# ---
# ## Clase 4 — Lógica, Condicionales y Loops

# %% [markdown]
# ### Ejercicio 4.1 — Semáforo de ventas
#
# Dado un `porcentaje_meta` (qué tan cerca está el equipo de ventas de su objetivo):
# ```python
# ventas_reales = 4_200_000
# meta_mensual  = 5_000_000
# ```
# Calcula el porcentaje de cumplimiento e imprime:
# - ≥ 100% → `"🟢 Meta superada"`
# - 80–99% → `"🟡 En camino"`
# - 60–79% → `"🟠 Necesita esfuerzo"`
# - < 60%  → `"🔴 Alerta crítica"`
#
# Además indica cuánto falta (o cuánto se superó) en pesos.

# %%
# Ejercicio 4.1
ventas_reales = 4_200_000
meta_mensual  = 5_000_000

# Tu código aquí:

# %% [markdown]
# ### Ejercicio 4.2 — FizzBuzz Data Science Edition
#
# Itera del 1 al 50 e imprime:
# - Si el número es múltiplo de 3 → `"Data"`
# - Si el número es múltiplo de 5 → `"Science"`
# - Si es múltiplo de ambos (3 y 5) → `"DataScience"`
# - Si no es múltiplo de ninguno → el número tal cual
#
# **Bonus:** cuenta cuántas veces apareció cada caso al final.

# %%
# Ejercicio 4.2

# %% [markdown]
# ### Ejercicio 4.3 — Generador de tabla de multiplicar
#
# Pide al usuario un número entre 1 y 12 con `input()` y genera su tabla de multiplicar completa (del 1 al 12).
#
# Valida que el número esté en el rango correcto — si no, muestra un mensaje de error y vuelve a pedir.
#
# Formato esperado:
# ```
# Tabla del 7:
#   7 ×  1 =   7
#   7 ×  2 =  14
#   ...
#   7 × 12 =  84
# ```

# %%
# Ejercicio 4.3 — ▶️ Ejecutar manualmente (usa input)

# %% [markdown]
# ### Ejercicio 4.4 — Analizador de lista con comprensión
#
# Dada esta lista de precios:
# ```python
# precios = [15990, 89990, 4990, 129990, 34990, 7490, 249990, 12990, 59990, 3490]
# ```
# Usando **list comprehensions** (una línea cada una):
# 1. Lista de precios con IVA (×1.19)
# 2. Solo los precios mayores a $20.000
# 3. Precios normalizados entre 0 y 1 (Min-Max)
# 4. Etiqueta para cada precio: `"caro"` si > $50.000, sino `"normal"`
#
# Imprime cada lista con su descripción.

# %%
# Ejercicio 4.4
precios = [15990, 89990, 4990, 129990, 34990, 7490, 249990, 12990, 59990, 3490]

# 1. Con IVA
con_iva = 

# 2. Solo mayores a $20.000
caros = 

# 3. Normalizados
normalizados = 

# 4. Etiquetas
etiquetas = 

# Imprimir resultados:

# %% [markdown]
# ---
# ## 🏆 Desafío Final — Mini Sistema de Votación
#
# Construye un programa que:
#
# 1. **Candidatos:** crea un diccionario con 4 candidatos y sus votos iniciales en 0:
#    ```python
#    candidatos = {"Alice": 0, "Bob": 0, "Carol": 0, "David": 0}
#    ```
#
# 2. **Votación:** usa un `while` para recibir votos indefinidamente. En cada iteración:
#    - Muestra los candidatos disponibles con sus votos actuales
#    - Pide el nombre del candidato a votar
#    - Si el nombre no existe → `"Candidato no encontrado"`
#    - Si es válido → suma 1 voto
#    - Si escribe `"fin"` → termina la votación
#
# 3. **Resultados:** al terminar, imprime:
#    - Votos totales emitidos
#    - Tabla de resultados con porcentaje de cada candidato
#    - Ganador (si hay empate, muéstralo)
#    - Barra de progreso ASCII para cada candidato
#
# **Pista:** la barra puede ser así: `█████░░░░░ 5/10 votos (50%)`

# %%
# Desafío Final
candidatos = {"Alice": 0, "Bob": 0, "Carol": 0, "David": 0}

# Tu código aquí:

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png { display: table-cell; text-align: center; vertical-align: middle; }
</style>
""")
